# %%
import numpy as np
from six.moves import cPickle
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. 일단 train wav파일과 label파일을 load 하자

# %% [markdown]
# - wav file load
#     - fs : 신호 길이, 데이터들 보아하니 신호길이는 16000(1초?)로 동일한걸로 보임
#     - data : 데이터 정보

# %%
from scipy.io import wavfile
file_num = '0'
fs, signal = wavfile.read('./train/train_02048.wav')

# %%
fs
# Out:
# 16000

# %%
signal.shape
# Out:
# (16000,)

# %%
plt.plot(signal)
plt.show()

# %% [markdown]
# - 음성데이터 stft 돌려서 상황을보자
#     - ?이거 막상할라니까 STFT를 잘모름 : 시계열을 일정한 시간 구간으로 나누고 각 구간에 대해 FFT를 통해서 주파수 스펙트럼을 만들어내는 방법정도?
#     - 최소 nfft, hop_length 정도는 알아야지

# %%
import librosa

# %%
signal
# Out:
# array([-214,  -78,  -55, ...,   49,  108,  -31], dtype=int16)

# %% [markdown]
# - STFT 결과

# %%
nfft=160
hop_length = int(fs/nfft)
stft_result = librosa.stft(np.float32(signal), n_fft=nfft, hop_length=hop_length)
print(stft_result.shape)
stft_result_db = librosa.amplitude_to_db(np.abs(stft_result), ref=np.max)
# Out:
# (81, 161)

# %%
import librosa.display as specdisplay

# %%
specdisplay.specshow(stft_result_db, sr=fs, y_axis='mel', x_axis='time')

# %%
plt.imshow(stft_result_db)
plt.colorbar()
plt.ylabel('Hz')
plt.ylim(0, nfft/2)
plt.xlabel('Time')
plt.show()

# %% [markdown]
# - 멜 스펙트럼은 주파수의 단위를 멜 단위(mel unit)로 바꾼 스펙트럼
#     - 멜단위는 사람이 귀로 들었을때 주로 들리는 부분을 강조하는 새로운 단위? 정도로 이해하면될듯함
#     - 위랑 아래 비교해보면 아래쪽 주파수영역이 좀더 강조된 결과처럼 보이는걸 알 수 있다.

# %%
hop_length = int(fs/nfft)
n_mles = nfft/2
mel_result = librosa.feature.melspectrogram(y=np.float32(signal), sr=fs, n_mels=n_mles, hop_length=hop_length)
mel_result_db = librosa.power_to_db(mel_result, ref=np.max)
print (mel_result_db.shape)
# Out:
# (80, 161)

# %%
plt.imshow(mel_result_db)
plt.colorbar()
plt.ylabel('Hz')
plt.ylim(0, nfft/2)
plt.xlabel('Time')
plt.show()

# %% [markdown]
# - label data(csv file) load
#     - 와.. 데이터 10만개
#     - 일단 이렇게하고 전체 행렬을 끄집어내야할듯

# %%
import pandas as pd

# %%
label_df = pd.read_csv('./train_answer.csv')
label_df
# Out:
#           id   bed  bird   cat   dog  down  eight  five  four    go  ...  \
# 0          0  0.00   0.0  0.00  0.00   0.0   0.00  0.25  0.00  0.00  ...
# 1          1  0.00   0.0  0.25  0.00   0.0   0.00  0.25  0.00  0.00  ...
# 2          2  0.00   0.0  0.00  0.25   0.0   0.00  0.25  0.25  0.00  ...
# 3          3  0.00   0.0  0.00  0.00   0.0   0.00  0.00  0.00  0.25  ...
# 4          4  0.00   0.0  0.00  0.00   0.0   0.25  0.00  0.00  0.00  ...
# ...      ...   ...   ...   ...   ...   ...    ...   ...   ...   ...  ...
# 99995  99995  0.00   0.0  0.00  0.00   0.0   0.25  0.00  0.00  0.00  ...
# 99996  99996  0.25   0.0  0.00  0.00   0.0   0.00  0.00  0.25  0.25  ...
# 99997  99997  0.00   0.0  0.00  0.00   0.0   0.00  0.00  0.00  0.25  ...
# 99998  99998  0.25   0.0  0.00  0.00   0.0   0.25  0.00  0.00  0.00  ...
# 99999  99999  0.00   0.0  0.25  0.00   0.0   0.00  0.25  0.00  0.00  ...
#
#        sheila  six  stop  three  tree   two   up  wow   yes  zero
# 0         0.0  0.0  0.25    0.0   0.0  0.00  0.0  0.0  0.00   0.0
# 1         0.0  0.0  0.00    0.0   0.0  0.00  0.0  0.0  0.00   0.0
# 2         0.0  0.0  0.00    0.0   0.0  0.00  0.0  0.0  0.00   0.0
# 3         0.0  0.0  0.00    0.0   0.0  0.00  0.0  0.0  0.00   0.0
# 4         0.0  0.0  0.00    0.0   0.0  0.00  0.0  0.0  0.00   0.0
# ...       ...  ...   ...    ...   ...   ...  ...  ...   ...   ...
# 99995     0.0  0.0  0.00    0.0   0.0  0.25  0.0  0.0  0.00   0.0
# 99996     0.0  0.0  0.00    0.0   0.0  0.00  0.0  0.0  0.00   0.0
# 99997     0.0  0.0  0.00    0.5   0.0  0.00  0.0  0.0  0.00   0.0
# 99998     0.0  0.0  0.00    0.0   0.0  0.00  0.0  0.0  0.00   0.0
# 99999     0.0  0.0  0.00    0.0   0.0  0.00  0.0  0.0  0.25   0.0
#
# [100000 rows x 31 columns]

# %%
label_array = label_df.values
label_array.shape
# Out:
# (100000, 31)
