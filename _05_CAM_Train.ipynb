# %%
from src import *
from utils import *
import os
import os.path as osp
import datetime

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from six.moves import cPickle
import torch

# %%
config_dict = {
    'gpu': 0, 
    'resume': './logs/pre_train_model/',
#     'resume': False,
    
    'max_iteration': 1000000,
    'lr': 0.001,
    'weight_decay': 0.0001,
    'momentum': 0.99,
    'batch_size': 2,
    'model': 'fcn8',
    'n_class': 1+1,
    'interval_validate': 500,
}

# log diectory 생성
#here = osp.dirname(osp.abspath(__file__))
here = osp.dirname('./')

now = datetime.datetime.now()
out = osp.join(here, 'logs', 'cam_'+now.strftime('%m%d_%H%M%S.%f'))

os.makedirs(out)
config_dict['out'] = out # log output directory 넣어줌
args = DictToObject(config_dict)

# GPU선정
os.environ['CUDA_VISIBLE_DEVICES'] = str(args.gpu)
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
cuda = torch.cuda.is_available()

# %% [markdown]
# # data loader

# %%
label_df = pd.read_csv('./train_answer.csv')

# %%
label_df.columns[1:args.n_class]
# Out:
# Index(['bed'], dtype='object')

# %%
# data loader

# 앞에서 9만번까지는 train 그 다음은 valid로 사용
train_dir_list = np.sort(glob.glob('./train/*.wav'))[:90000]
valid_dir_list = np.sort(glob.glob('./train/*.wav'))[90000:]

train_dataset = GetTrainDataset(train_dir_list, class_list=label_df.columns[1:args.n_class], label_image=False) 
valid_dataset = GetTrainDataset(valid_dir_list, class_list=label_df.columns[1:args.n_class], label_image=False) 

train_loader = DataLoader(dataset=train_dataset, batch_size=args.batch_size, shuffle=True, num_workers=0) # 이게 worker 0이어야 에러가안남 broken pipe인지뭔지
valid_loader = DataLoader(dataset=valid_dataset, batch_size=args.batch_size, shuffle=True, num_workers=0) # 이게 worker 0이어야 에러가안남 broken pipe인지뭔지

# %% [markdown]
# # model

# %%
model = CAM8s(n_class=args.n_class)
start_epoch = 0
start_iteration = 0
if args.resume:
    checkpoint = torch.load(args.resume+'/checkpoint.pth.tar')
    
    # backbone 부분만 불러올려고 쓸모없는 정보는 지워버림
    # class dependancy 있는 친구들 제거
    new_model_dict = model.state_dict()
    pretrained_dict = checkpoint['model_state_dict']
    pretrained_dict = {k: v for k, v in pretrained_dict.items() if 'block' in k}
    new_model_dict.update(pretrained_dict)
    
    #model.load_state_dict(checkpoint['model_state_dict'])
    model.load_state_dict(new_model_dict)
    start_epoch = checkpoint['epoch']
    start_iteration = checkpoint['iteration']

if cuda:
    model = model.cuda()
    
# optim = torch.optim.SGD(model.parameters(),
# optim = torch.optim.RMSprop(model.parameters(),
#     lr=args.lr,
#     momentum=args.momentum,
#     weight_decay=args.weight_decay)
optim = torch.optim.Adam(model.parameters(),
    lr=args.lr,
    weight_decay=args.weight_decay)
# backbone 로드하는거면 이거 필요없는듯함 
#if args.resume:
#    optim.load_state_dict(checkpoint['optim_state_dict'])


trainer = CAM_Trainer(
    cuda=cuda,
    model=model,
    optimizer=optim,
    train_loader=train_loader,
    val_loader=valid_loader,
    out=args.out, # log output director
    max_iter=args.max_iteration,
    n_class=args.n_class,
    interval_validate=args.interval_validate,
)

# %%
#trainer.epoch = start_epoch
#trainer.iteration = start_iteration
trainer.train()
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Train', max=23.0, style=ProgressStyle(description_width='…
# HBox(children=(FloatProgress(value=0.0, description='Train epoch=0', max=45000.0, style=ProgressStyle(descript…
# HBox(children=(FloatProgress(value=0.0, description='Valid iteration=0', max=5000.0, style=ProgressStyle(descr…
# [0 1]
# [0.4817285 0.518794 ]
#  iteration : 499, loss :               1.5292
# HBox(children=(FloatProgress(value=0.0, description='Valid iteration=500', max=5000.0, style=ProgressStyle(des…
# [0 1]
# [0.86864454 0.3771911 ]
#  iteration : 999, loss :               0.8439
# HBox(children=(FloatProgress(value=0.0, description='Valid iteration=1000', max=5000.0, style=ProgressStyle(de…
# [0 1]
# [0.79315746 0.41239542]
#  iteration : 1499, loss :               0.6585
# HBox(children=(FloatProgress(value=0.0, description='Valid iteration=1500', max=5000.0, style=ProgressStyle(de…
# [0 1]
# [0.899967   0.33375326]
#  iteration : 1999, loss :               0.5884
# HBox(children=(FloatProgress(value=0.0, description='Valid iteration=2000', max=5000.0, style=ProgressStyle(de…
# [0 1]
# [0.9218617  0.27655923]
#  iteration : 2499, loss :               0.7172
# HBox(children=(FloatProgress(value=0.0, description='Valid iteration=2500', max=5000.0, style=ProgressStyle(de…
# [0 1]
# [0.854661   0.34141457]
#  iteration : 2999, loss :               0.5817
# HBox(children=(FloatProgress(value=0.0, description='Valid iteration=3000', max=5000.0, style=ProgressStyle(de…
# [0 1]
# [0.91929245 0.25060403]
#  iteration : 3499, loss :               0.6975
# HBox(children=(FloatProgress(value=0.0, description='Valid iteration=3500', max=5000.0, style=ProgressStyle(de…
# [0 1]
# [0.8546906  0.33072048]
#  iteration : 3999, loss :               0.6183
# HBox(children=(FloatProgress(value=0.0, description='Valid iteration=4000', max=5000.0, style=ProgressStyle(de…
# [0 1]
# [0.92358464 0.30827725]
#  iteration : 4499, loss :               0.6659
# HBox(children=(FloatProgress(value=0.0, description='Valid iteration=4500', max=5000.0, style=ProgressStyle(de…
# [0 1]
# [0.89052516 0.32845542]
#  iteration : 4999, loss :               0.5295
# HBox(children=(FloatProgress(value=0.0, description='Valid iteration=5000', max=5000.0, style=ProgressStyle(de…
# [0 1]
# [0.93894124 0.21462049]
#  iteration : 5499, loss :               1.7819
# HBox(children=(FloatProgress(value=0.0, description='Valid iteration=5500', max=5000.0, style=ProgressStyle(de…
# [0 1]
# [0.91638166 0.254497  ]
#  iteration : 5949, loss :               1.8411
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-52705d13ed16> in <module>
#       1 #trainer.epoch = start_epoch
#       2 #trainer.iteration = start_iteration
# ----> 3 trainer.train()
#
# D:\Dropbox\KSH\project\01_SplitSound\src\CAM_TRAIN.py in train(self)
#     194                                  desc='Train'):
#     195             self.epoch = epoch
# --> 196             self.train_epoch()
#     197             if self.iteration >= self.max_iter:
#     198                 break
#
# D:\Dropbox\KSH\project\01_SplitSound\src\CAM_TRAIN.py in train_epoch(self)
#     142         for batch_idx, (data, target) in tqdm.notebook.tqdm(
#     143                 enumerate(self.train_loader), total=len(self.train_loader),
# --> 144                 desc='Train epoch={}'.format(self.epoch), leave=False):
#     145             if np.random.randint(10)>3:
#     146                 if target.cpu().numpy()[0, 0] == 1:
#
# d:\dropbox\ksh\project\shenv\lib\site-packages\tqdm\notebook.py in __iter__(self, *args, **kwargs)
#     215     def __iter__(self, *args, **kwargs):
#     216         try:
# --> 217             for obj in super(tqdm_notebook, self).__iter__(*args, **kwargs):
#     218                 # return super(tqdm...) will not catch exception
#     219                 yield obj
#
# d:\dropbox\ksh\project\shenv\lib\site-packages\tqdm\std.py in __iter__(self)
#    1127
#    1128         try:
# -> 1129             for obj in iterable:
#    1130                 yield obj
#    1131                 # Update and possibly print the progressbar.
#
# d:\dropbox\ksh\project\shenv\lib\site-packages\torch\utils\data\dataloader.py in __next__(self)
#     343
#     344     def __next__(self):
# --> 345         data = self._next_data()
#     346         self._num_yielded += 1
#     347         if self._dataset_kind == _DatasetKind.Iterable and \
#
# d:\dropbox\ksh\project\shenv\lib\site-packages\torch\utils\data\dataloader.py in _next_data(self)
#     383     def _next_data(self):
#     384         index = self._next_index()  # may raise StopIteration
# --> 385         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     386         if self._pin_memory:
#     387             data = _utils.pin_memory.pin_memory(data)
#
# d:\dropbox\ksh\project\shenv\lib\site-packages\torch\utils\data\_utils\fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# d:\dropbox\ksh\project\shenv\lib\site-packages\torch\utils\data\_utils\fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# D:\Dropbox\KSH\project\01_SplitSound\utils\run_utils.py in __getitem__(self, index)
#      51     def __getitem__(self, index):
#      52         # get item이 호출될 때, directory 에서 파일 로드해서 melspectrogram 연산
# ---> 53         fs, signal = wavfile.read(self.dir_list[index])
#      54         mel_result = self.get_melspectrogram(signal, fs=fs, nfft=320, normalize=True)
#      55         w, h = mel_result.shape
#
# d:\dropbox\ksh\project\shenv\lib\site-packages\scipy\io\wavfile.py in read(filename, mmap)
#     542         mmap = False
#     543     else:
# --> 544         fid = open(filename, 'rb')
#     545
#     546     try:
#
# KeyboardInterrupt:

# %%
batch_idx, (data, target) = next(enumerate(valid_loader))

val_loss = 0
visualizations = []
label_trues, label_preds = [], []
data, target = data.cuda(), target.cuda()
data, target = Variable(data), Variable(target).to(dtype=torch.long) # target data type 이슈
sys.stdout.write('\r {}'.format(batch_idx))
with torch.no_grad():
    score = model(data)

# %%
for i in range(31):
    plt.figure(figsize=(10, 12))
    plt.title("target label : {}".format(np.array(target[0, i, 0, 0].cpu())))
    result = np.array(score[0, i, :, :].cpu())
#     result[result<0.5] = 0
#     result[result>0.5] = 1
    plt.imshow(result)
    print (np.mean(result))
    plt.colorbar()
    plt.show()
